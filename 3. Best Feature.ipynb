# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
random_forest = pd.read_pickle('/Users/irfanularifa/Documents/TA_FIX/0. Dataset/GA-RFC.pickle')
ada_boost = pd.read_pickle('/Users/irfanularifa/Documents/TA_FIX/0. Dataset/GA-ABC.pickle')
gradient_boost = pd.read_pickle('/Users/irfanularifa/Documents/TA_FIX/0. Dataset/GA-GBC.pickle')

# %%
random_forest.sort_values('objective_scores', ascending=False)
# Out:
#     run_idx  objective_scores  best_scores  num_features  \
# 18       19           0.81875      0.81875           230
# 19       20           0.81250      0.81250           267
# 1         2           0.81250      0.81250           250
# 5         6           0.81250      0.81250           240
# 7         8           0.80625      0.80625           256
# 17       18           0.80625      0.80625           276
# 8         9           0.80625      0.80625           252
# 10       11           0.80625      0.80625           249
# 4         5           0.80625      0.80625           255
# 3         4           0.80625      0.80625           248
# 2         3           0.80625      0.80625           248
# 11       12           0.80000      0.80000           255
# 12       13           0.80000      0.80000           246
# 15       16           0.80000      0.80000           273
# 16       17           0.80000      0.80000           236
# ...

# %%
ada_boost.sort_values('objective_scores', ascending=False)
# Out:
#     run_idx  objective_scores  best_scores  num_features  \
# 14       15           0.79375      0.79375           261
# 12       13           0.79375      0.79375           249
# 17       18           0.78750      0.78750           281
# 16       17           0.78750      0.78750           264
# 18       19           0.78125      0.78125           257
# 11       12           0.78125      0.78125           259
# 19       20           0.77500      0.77500           246
# 2         3           0.77500      0.77500           254
# 6         7           0.77500      0.77500           253
# 7         8           0.77500      0.77500           244
# 15       16           0.77500      0.77500           262
# 5         6           0.76875      0.76875           246
# 9        10           0.76875      0.76875           254
# 10       11           0.76250      0.76250           263
# 13       14           0.76250      0.76250           268
# ...

# %%
gradient_boost.sort_values('objective_scores', ascending=False)
# Out:
#     run_idx  objective_scores  best_scores  num_features  \
# 6         7           0.79375      0.79375           255
# 17       18           0.78750      0.78750           251
# 16       17           0.78750      0.78750           238
# 8         9           0.78750      0.78750           252
# 13       14           0.78125      0.78125           245
# 3         4           0.78125      0.78125           262
# 5         6           0.78125      0.78125           237
# 1         2           0.78125      0.78125           257
# 19       20           0.77500      0.77500           247
# 9        10           0.77500      0.77500           258
# 11       12           0.77500      0.77500           240
# 14       15           0.77500      0.77500           247
# 15       16           0.76875      0.76875           256
# 0         1           0.76875      0.76875           254
# 12       13           0.76875      0.76875           257
# ...

# %%
plt.rcParams["figure.figsize"] = [15.00, 4.50]
plt.rcParams["figure.autolayout"] = True
f, axes = plt.subplots(1, 3)
sns.histplot(data=random_forest, x="best_scores", kde=True, bins=5, ax= axes[0], )
sns.histplot(data=ada_boost, x="best_scores", kde=True, bins=5, ax= axes[1])
sns.histplot(data=gradient_boost, x="best_scores", kde=True, bins=5, ax= axes[2])
plt.show()

# %%
plt.rcParams["figure.figsize"] = [15.00, 4.50]
plt.rcParams["figure.autolayout"] = True
f, axes = plt.subplots(1, 3)
sns.barplot(data=random_forest, x="run_idx", y="objective_scores", ax= axes[0])
sns.barplot(data=ada_boost, x="run_idx", y="objective_scores", ax= axes[1])
sns.barplot(data=gradient_boost, x="run_idx", y="objective_scores", ax= axes[2])
plt.show()

# %%
fig1 = random_forest.sort_values(by='objective_scores', ascending=False, ignore_index=True)['plot'][0]
fig2 = ada_boost.sort_values(by='objective_scores', ascending=False, ignore_index=True)['plot'][0]
fig3 = gradient_boost.sort_values(by='objective_scores', ascending=False, ignore_index=True)['plot'][0]
dic1 = fig1.to_dict()
dic2 = fig2.to_dict()
dic3 = fig3.to_dict()
plt.rcParams["figure.figsize"] = [5.70, 4.50]
plt.rcParams["figure.autolayout"] = True
sns.lineplot(x=dic1['data'][0]['x'], y=dic1['data'][0]['y'])
sns.lineplot(x=dic2['data'][0]['x'], y=dic2['data'][0]['y'])
sns.lineplot(x=dic3['data'][0]['x'], y=dic3['data'][0]['y'])
plt.xlabel("Iteration")
plt.ylabel("Objective Score")
plt.legend(labels=["Random Forest","AdaBoost","Gradient Boosting"])

# %%
fig = random_forest.sort_values(by='objective_scores', ascending=False, ignore_index=True)['plot'][0]
dict_ =fig.to_dict()
plt.rcParams["figure.figsize"] = [5.70, 4.50]
plt.rcParams["figure.autolayout"] = True
sns.lineplot(x=dict_['data'][0]['x'], y=dict_['data'][0]['y'])
plt.xlabel("Iteration")
plt.ylabel("Objective Score")
# Out:
# Text(0, 0.5, 'Objective Score')

# %%
fig = ada_boost.sort_values(by='objective_scores', ascending=False, ignore_index=True)['plot'][0]
dict_ =fig.to_dict()
plt.rcParams["figure.figsize"] = [5.70, 4.50]
plt.rcParams["figure.autolayout"] = True
sns.lineplot(x=dict_['data'][0]['x'], y=dict_['data'][0]['y'])
plt.xlabel("Iteration")
plt.ylabel("Objective Score")
# Out:
# Text(0, 0.5, 'Objective Score')

# %%
fig = gradient_boost.sort_values(by='objective_scores', ascending=False, ignore_index=True)['plot'][0]
dict_ =fig.to_dict()
plt.rcParams["figure.figsize"] = [5.70, 4.50]
plt.rcParams["figure.autolayout"] = True
sns.lineplot(x=dict_['data'][0]['x'], y=dict_['data'][0]['y'])
plt.xlabel("Iteration")
plt.ylabel("Best Score")
# Out:
# Text(0, 0.5, 'Best Score')

# %%
best_rf = random_forest.sort_values(by='objective_scores', ascending=False, ignore_index=True)['selected_features'][0]
best_ab = ada_boost.sort_values(by='objective_scores', ascending=False, ignore_index=True)['selected_features'][0]
best_gb = gradient_boost.sort_values(by='objective_scores', ascending=False, ignore_index=True)['selected_features'][0]
best_rf = pd.DataFrame(best_rf)
best_ab = pd.DataFrame(best_ab)
best_gb = pd.DataFrame(best_gb)
best_rf.to_pickle('/Users/irfanularifa/Documents/TA_FIX/0. Dataset/Best Feature Random Forest.pickle')
best_ab.to_pickle('/Users/irfanularifa/Documents/TA_FIX/0. Dataset/Best Feature Ada Boost.pickle')
best_gb.to_pickle('/Users/irfanularifa/Documents/TA_FIX/0. Dataset/Best Feature Gradient Boosting.pickle')
