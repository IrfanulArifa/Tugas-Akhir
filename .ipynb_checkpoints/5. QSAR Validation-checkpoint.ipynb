# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import joblib
import matplotlib.pyplot as plt

# %%
best_estimator_rfc = joblib.load('/Users/irfanularifa/Documents/TA_FIX/0. Dataset/RF_best.pickle')
best_estimator_abc = joblib.load('/Users/irfanularifa/Documents/TA_FIX/0. Dataset/AB_best.pickle')
best_estimator_gbc = joblib.load('/Users/irfanularifa/Documents/TA_FIX/0. Dataset/GB_best.pickle')

# %%
X_train = pd.read_csv('/Users/irfanularifa/Documents/TA_FIX/0. Dataset/Training.csv')
X_train
# Out:
#      nAcid   ALogP    ALogp2      AMR       apol  naAromAtom  nAromBond  \
# 0        1 -0.3299  0.108834  39.5003  65.228653          21         24
# 1        1 -1.1845  1.403040  56.3007  67.606411          15         17
# 2        1  0.0239  0.000571  40.3193  66.479653          21         24
# 3        1 -0.4296  0.184556  42.6228  76.076204          22         24
# 4        1 -0.6399  0.409472  59.7313  78.211790          18         19
# ..     ...     ...       ...      ...        ...         ...        ...
# 155      1 -1.0395  1.080560  40.0833  65.908653          21         24
# 156      1 -0.7613  0.579578  43.3476  68.575825          21         24
# 157      1 -0.9778  0.956093  65.8072  85.634169          21         23
# 158      1 -0.4468  0.199630  33.7560  59.041481          21         24
# 159      1  0.5391  0.290629  40.1189  70.697825          22         24
#
#      nAtom  nHeavyAtom  nH  ...    WTPT-2     WTPT-3     WTPT-4     WTPT-5  \
# ...

# %%
y_train = X_train['Label']
y_train
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 155    0
# 156    1
# 157    1
# 158    1
# 159    0
# Name: Label, Length: 160, dtype: int64

# %%
X_train = X_train.drop(['Label','pIC50'], axis=1)
X_train
# Out:
#      nAcid   ALogP    ALogp2      AMR       apol  naAromAtom  nAromBond  \
# 0        1 -0.3299  0.108834  39.5003  65.228653          21         24
# 1        1 -1.1845  1.403040  56.3007  67.606411          15         17
# 2        1  0.0239  0.000571  40.3193  66.479653          21         24
# 3        1 -0.4296  0.184556  42.6228  76.076204          22         24
# 4        1 -0.6399  0.409472  59.7313  78.211790          18         19
# ..     ...     ...       ...      ...        ...         ...        ...
# 155      1 -1.0395  1.080560  40.0833  65.908653          21         24
# 156      1 -0.7613  0.579578  43.3476  68.575825          21         24
# 157      1 -0.9778  0.956093  65.8072  85.634169          21         23
# 158      1 -0.4468  0.199630  33.7560  59.041481          21         24
# 159      1  0.5391  0.290629  40.1189  70.697825          22         24
#
#      nAtom  nHeavyAtom  nH  ...       AMW     WTPT-1    WTPT-2     WTPT-3  \
# ...

# %%
X_test = pd.read_csv('/Users/irfanularifa/Documents/TA_FIX/0. Dataset/Testing.csv')
X_test
# Out:
#     nAcid   ALogP    ALogp2      AMR       apol  naAromAtom  nAromBond  nAtom  \
# 0       1 -1.1628  1.352104  47.7649  69.364239          18         19     57
# 1       1 -0.4155  0.172640  54.8174  79.176583          21         23     67
# 2       0  0.2621  0.068696  56.8592  68.188825          17         18     60
# 3       1  0.8192  0.671089  56.7211  77.486411          21         23     64
# 4       1  0.5291  0.279947  44.0969  68.847032          21         24     56
# ..    ...     ...       ...      ...        ...         ...        ...    ...
# 63      1 -0.1148  0.013179  35.6297  63.495860          21         24     53
# 64      1 -1.0554  1.113869  71.5682  88.826134          18         19     77
# 65      1 -0.2678  0.071717  63.9795  60.039446          12         12     52
# 66      1  0.4260  0.181476  62.1658  59.237446          12         12     51
# 67      1 -0.9199  0.846216  61.0438  69.229411          15         17     59
#
# ...

# %%
y_test = X_test['Label']
y_test
# Out:
# 0     0
# 1     1
# 2     0
# 3     1
# 4     1
#      ..
# 63    1
# 64    1
# 65    0
# 66    0
# 67    1
# Name: Label, Length: 68, dtype: int64

# %%
X_test = X_test.drop(['Label','pIC50'], axis=1)
X_test
# Out:
#     nAcid   ALogP    ALogp2      AMR       apol  naAromAtom  nAromBond  nAtom  \
# 0       1 -1.1628  1.352104  47.7649  69.364239          18         19     57
# 1       1 -0.4155  0.172640  54.8174  79.176583          21         23     67
# 2       0  0.2621  0.068696  56.8592  68.188825          17         18     60
# 3       1  0.8192  0.671089  56.7211  77.486411          21         23     64
# 4       1  0.5291  0.279947  44.0969  68.847032          21         24     56
# ..    ...     ...       ...      ...        ...         ...        ...    ...
# 63      1 -0.1148  0.013179  35.6297  63.495860          21         24     53
# 64      1 -1.0554  1.113869  71.5682  88.826134          18         19     77
# 65      1 -0.2678  0.071717  63.9795  60.039446          12         12     52
# 66      1  0.4260  0.181476  62.1658  59.237446          12         12     51
# 67      1 -0.9199  0.846216  61.0438  69.229411          15         17     59
#
# ...

# %%
best_feature_rfc = pd.read_pickle('/Users/irfanularifa/Documents/TA_FIX/0. Dataset/Best Feature Random Forest.pickle')
best_feature_abc = pd.read_pickle('/Users/irfanularifa/Documents/TA_FIX/0. Dataset/Best Feature Ada Boost.pickle')
best_feature_gbc = pd.read_pickle('/Users/irfanularifa/Documents/TA_FIX/0. Dataset/Best Feature Gradient Boosting.pickle')

# %%
best_feature_rfc = np.array(best_feature_rfc[0])
best_feature_abc = np.array(best_feature_abc[0])
best_feature_gbc = np.array(best_feature_gbc[0])

# %%
X_train_rfc = X_train[best_feature_rfc]
X_train_abc = X_train[best_feature_abc]
X_train_gbc = X_train[best_feature_gbc]

# %%
X_test_rfc = X_test[best_feature_rfc]
X_test_abc = X_test[best_feature_abc]
X_test_gbc = X_test[best_feature_gbc]

# %% [markdown]
# # Random Forest

# %%
X_train_rfc
# Out:
#       ALogP       apol  naAromAtom  nHeavyAtom  nO        ATS0m        ATS1m  \
# 0   -0.3299  65.228653          21          32   3  6293.066947  6118.706025
# 1   -1.1845  67.606411          15          32   3  5403.400155  6017.722380
# 2    0.0239  66.479653          21          35   3  6263.446540  6521.749659
# 3   -0.4296  76.076204          22          35   3  5516.669523  6210.926483
# 4   -0.6399  78.211790          18          36   4  5774.669652  6451.278604
# ..      ...        ...         ...         ...  ..          ...          ...
# 155 -1.0395  65.908653          21          33   3  5376.824617  6005.418273
# 156 -0.7613  68.575825          21          33   3  5380.888873  6077.820581
# 157 -0.9778  85.634169          21          40   5  6518.410136  7400.567989
# 158 -0.4468  59.041481          21          30   3  6000.474449  5781.749431
# 159  0.5391  70.697825          22          34   4  5532.993018  6033.808641
#
# ...

# %%
X_test_rfc
# Out:
#      ALogP       apol  naAromAtom  nHeavyAtom  nO        ATS0m        ATS1m  \
# 0  -1.1628  69.364239          18          34   4  5530.960890  5935.748593
# 1  -0.4155  79.176583          21          36   3  5715.913764  6463.433736
# 2   0.2621  68.188825          17          35   4  6379.214676  6403.399541
# 3   0.8192  77.486411          21          37   3  7185.227211  6924.721034
# 4   0.5291  68.847032          21          32   2  6132.479331  6011.279641
# ..     ...        ...         ...         ...  ..          ...          ...
# 63 -0.1148  63.495860          21          33   3  5757.227031  6137.188629
# 64 -1.0554  88.826134          18          39   4  6215.590527  7028.827539
# 65 -0.2678  60.039446          12          30   5  5116.524150  5417.942372
# 66  0.4260  59.237446          12          29   4  4860.556149  5177.878515
# 67 -0.9199  69.229411          15          32   3  6299.163331  6215.322509
#
# ...

# %%
y_pred_train_rfc = best_estimator_rfc.predict(X_train_rfc)
y_pred_test_rfc = best_estimator_rfc.predict(X_test_rfc)

# %%
print(f'Random Forest model train score: {accuracy_score(y_train, y_pred_train_rfc)}')
print(f'Random Forest model test score: {accuracy_score(y_test, y_pred_test_rfc)}')
# Out:
# Random Forest model train score: 0.98125
# Random Forest model test score: 0.7647058823529411

# %%
print('Random Forest Model Report')
print(classification_report(y_test,y_pred_test_rfc))
print(confusion_matrix(y_train,y_pred_train_rfc))
print(classification_report(y_test,y_pred_test_rfc))
print(confusion_matrix(y_test,y_pred_test_rfc))
# Out:
# Random Forest Model Report
#               precision    recall  f1-score   support
#
#            0       0.95      0.58      0.72        36
#            1       0.67      0.97      0.79        32
#
#     accuracy                           0.76        68
#    macro avg       0.81      0.78      0.76        68
# weighted avg       0.82      0.76      0.76        68
#
# [[66  3]
#  [ 0 91]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.58      0.72        36
#            1       0.67      0.97      0.79        32
#
#     accuracy                           0.76        68
#    macro avg       0.81      0.78      0.76        68
# weighted avg       0.82      0.76      0.76        68
#
# [[21 15]
#  [ 1 31]]

# %%
X_train_abc
# Out:
#      naAromAtom  nAromBond  nAtom  nHeavyAtom  nH  nC  nN  nO   nF  \
# 0            21         24     53          32  21  24   4   3  0.0
# 1            15         17     59          32  27  24   4   3  1.0
# 2            21         24     56          35  21  25   4   3  3.0
# 3            22         24     63          35  28  30   2   3  0.0
# 4            18         19     66          36  30  30   2   4  0.0
# ..          ...        ...    ...         ...  ..  ..  ..  ..  ...
# 155          21         24     54          33  21  25   5   3  0.0
# 156          21         24     58          33  25  25   5   3  0.0
# 157          21         23     73          40  33  32   3   5  0.0
# 158          21         24     47          30  17  22   4   3  0.0
# 159          22         24     59          34  25  27   3   4  0.0
#
#            ATS1m  ...        VABC         TWC      SRW5      SRW7      SRW9  \
# 0    6118.706025  ...  374.845539  145.796041  2.397895  4.727388  6.842683
# ...

# %%
X_test_abc
# Out:
#     naAromAtom  nAromBond  nAtom  nHeavyAtom  nH  nC  nN  nO   nF  \
# 0           18         19     57          34  23  27   3   4  0.0
# 1           21         23     67          36  31  30   3   3  0.0
# 2           17         18     60          35  25  24   4   4  3.0
# 3           21         23     64          37  27  29   3   3  1.0
# 4           21         24     56          32  24  26   3   2  0.0
# ..         ...        ...    ...         ...  ..  ..  ..  ..  ...
# 63          21         24     53          33  20  24   4   3  2.0
# 64          18         19     77          39  38  33   2   4  0.0
# 65          12         12     52          30  22  21   4   5  0.0
# 66          12         12     51          29  22  21   4   4  0.0
# 67          15         17     59          32  27  24   4   3  0.0
#
#           ATS1m  ...        VABC         TWC      SRW5      SRW7      SRW9  \
# 0   5935.748593  ...  424.662974  148.491862  2.397895  4.595120  6.605298
# ...

# %%
y_pred_train_abc = best_estimator_abc.predict(X_train_abc)
y_pred_test_abc = best_estimator_abc.predict(X_test_abc)

# %%
print(f'Ada Boost model train score: {accuracy_score(y_train, y_pred_train_abc)}')
print(f'Ada Boost model test score: {accuracy_score(y_test, y_pred_test_abc)}')
# Out:
# Ada Boost model train score: 0.96875
# Ada Boost model test score: 0.6617647058823529

# %%
print('Ada Boosting Model Report')
print(classification_report(y_train,y_pred_train_abc))
print(confusion_matrix(y_train,y_pred_train_abc))
print(classification_report(y_test,y_pred_test_abc))
print(confusion_matrix(y_test,y_pred_test_abc))
# Out:
# Ada Boosting Model Report
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96        69
#            1       0.97      0.98      0.97        91
#
#     accuracy                           0.97       160
#    macro avg       0.97      0.97      0.97       160
# weighted avg       0.97      0.97      0.97       160
#
# [[66  3]
#  [ 2 89]]
#               precision    recall  f1-score   support
#
#            0       0.76      0.53      0.62        36
#            1       0.60      0.81      0.69        32
#
#     accuracy                           0.66        68
#    macro avg       0.68      0.67      0.66        68
# weighted avg       0.69      0.66      0.66        68
#
# [[19 17]
#  [ 6 26]]

# %% [markdown]
# # Gradient Boosting

# %%
X_train_abc
# Out:
#      naAromAtom  nAromBond  nAtom  nHeavyAtom  nH  nC  nN  nO   nF  \
# 0            21         24     53          32  21  24   4   3  0.0
# 1            15         17     59          32  27  24   4   3  1.0
# 2            21         24     56          35  21  25   4   3  3.0
# 3            22         24     63          35  28  30   2   3  0.0
# 4            18         19     66          36  30  30   2   4  0.0
# ..          ...        ...    ...         ...  ..  ..  ..  ..  ...
# 155          21         24     54          33  21  25   5   3  0.0
# 156          21         24     58          33  25  25   5   3  0.0
# 157          21         23     73          40  33  32   3   5  0.0
# 158          21         24     47          30  17  22   4   3  0.0
# 159          22         24     59          34  25  27   3   4  0.0
#
#            ATS1m  ...        VABC         TWC      SRW5      SRW7      SRW9  \
# 0    6118.706025  ...  374.845539  145.796041  2.397895  4.727388  6.842683
# ...

# %%
X_test_abc
# Out:
#     naAromAtom  nAromBond  nAtom  nHeavyAtom  nH  nC  nN  nO   nF  \
# 0           18         19     57          34  23  27   3   4  0.0
# 1           21         23     67          36  31  30   3   3  0.0
# 2           17         18     60          35  25  24   4   4  3.0
# 3           21         23     64          37  27  29   3   3  1.0
# 4           21         24     56          32  24  26   3   2  0.0
# ..         ...        ...    ...         ...  ..  ..  ..  ..  ...
# 63          21         24     53          33  20  24   4   3  2.0
# 64          18         19     77          39  38  33   2   4  0.0
# 65          12         12     52          30  22  21   4   5  0.0
# 66          12         12     51          29  22  21   4   4  0.0
# 67          15         17     59          32  27  24   4   3  0.0
#
#           ATS1m  ...        VABC         TWC      SRW5      SRW7      SRW9  \
# 0   5935.748593  ...  424.662974  148.491862  2.397895  4.595120  6.605298
# ...

# %%
y_pred_train_gbc = best_estimator_gbc.predict(X_train_gbc)
y_pred_test_gbc = best_estimator_gbc.predict(X_test_gbc)

# %%
print(f'Gradient Boost model train score: {accuracy_score(y_train, y_pred_train_gbc)}')
print(f'Gradient Boost model test score: {accuracy_score(y_test, y_pred_test_gbc)}')
# Out:
# Gradient Boost model train score: 0.98125
# Gradient Boost model test score: 0.8088235294117647

# %%
print('Gradient Boosting Model Report')
print(classification_report(y_test,y_pred_test_gbc))
print(confusion_matrix(y_train,y_pred_train_gbc))
print(classification_report(y_test,y_pred_test_gbc))
print(confusion_matrix(y_test,y_pred_test_gbc))
# Out:
# Gradient Boosting Model Report
#               precision    recall  f1-score   support
#
#            0       0.90      0.72      0.80        36
#            1       0.74      0.91      0.82        32
#
#     accuracy                           0.81        68
#    macro avg       0.82      0.81      0.81        68
# weighted avg       0.82      0.81      0.81        68
#
# [[66  3]
#  [ 0 91]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.72      0.80        36
#            1       0.74      0.91      0.82        32
#
#     accuracy                           0.81        68
#    macro avg       0.82      0.81      0.81        68
# weighted avg       0.82      0.81      0.81        68
#
# [[26 10]
#  [ 3 29]]
