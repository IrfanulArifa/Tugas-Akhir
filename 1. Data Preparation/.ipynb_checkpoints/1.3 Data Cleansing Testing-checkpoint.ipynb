# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import VarianceThreshold

# %%
Testing = pd.read_csv('/Users/irfanularifa/Documents/TA_FIX/0. Dataset/Testing.csv')
Testing
# Out:
#     nAcid   ALogP    ALogp2      AMR       apol  naAromAtom  nAromBond  nAtom  \
# 0       1 -1.1628  1.352104  47.7649  69.364239          18         19     57
# 1       1 -0.4155  0.172640  54.8174  79.176583          21         23     67
# 2       0  0.2621  0.068696  56.8592  68.188825          17         18     60
# 3       1  0.8192  0.671089  56.7211  77.486411          21         23     64
# 4       1  0.5291  0.279947  44.0969  68.847032          21         24     56
# ..    ...     ...       ...      ...        ...         ...        ...    ...
# 63      1 -0.1148  0.013179  35.6297  63.495860          21         24     53
# 64      1 -1.0554  1.113869  71.5682  88.826134          18         19     77
# 65      1 -0.2678  0.071717  63.9795  60.039446          12         12     52
# 66      1  0.4260  0.181476  62.1658  59.237446          12         12     51
# 67      1 -0.9199  0.846216  61.0438  69.229411          15         17     59
#
# ...

# %%
y_test = Testing['Label']
y_test
# Out:
# 0     0
# 1     1
# 2     0
# 3     1
# 4     1
#      ..
# 63    1
# 64    1
# 65    0
# 66    0
# 67    1
# Name: Label, Length: 68, dtype: int64

# %%
X_test = Testing.drop(['Label'], axis = 1)
X_test
# Out:
#     nAcid   ALogP    ALogp2      AMR       apol  naAromAtom  nAromBond  nAtom  \
# 0       1 -1.1628  1.352104  47.7649  69.364239          18         19     57
# 1       1 -0.4155  0.172640  54.8174  79.176583          21         23     67
# 2       0  0.2621  0.068696  56.8592  68.188825          17         18     60
# 3       1  0.8192  0.671089  56.7211  77.486411          21         23     64
# 4       1  0.5291  0.279947  44.0969  68.847032          21         24     56
# ..    ...     ...       ...      ...        ...         ...        ...    ...
# 63      1 -0.1148  0.013179  35.6297  63.495860          21         24     53
# 64      1 -1.0554  1.113869  71.5682  88.826134          18         19     77
# 65      1 -0.2678  0.071717  63.9795  60.039446          12         12     52
# 66      1  0.4260  0.181476  62.1658  59.237446          12         12     51
# 67      1 -0.9199  0.846216  61.0438  69.229411          15         17     59
#
# ...

# %%
Selector = VarianceThreshold(threshold=0.5)
X_test = Selector.fit_transform(X_test)
X_test
# Out:
# array([[-1.16280000e+00,  1.35210384e+00,  4.77649000e+01, ...,
#          5.85700000e+00,  1.76000000e+02,  6.21968269e+00],
#        [-4.15500000e-01,  1.72640250e-01,  5.48174000e+01, ...,
#          9.33700000e+00,  1.92000000e+02,  7.52143350e+00],
#        [ 2.62100000e-01,  6.86964100e-02,  5.68592000e+01, ...,
#          4.62600000e+00,  1.76000000e+02,  6.22184875e+00],
#        ...,
#        [-2.67800000e-01,  7.17168400e-02,  6.39795000e+01, ...,
#          1.63900000e+00,  1.56000000e+02,  6.13786862e+00],
#        [ 4.26000000e-01,  1.81476000e-01,  6.21658000e+01, ...,
#          2.40600000e+00,  1.52000000e+02,  5.42458121e+00],
#        [-9.19900000e-01,  8.46216010e-01,  6.10438000e+01, ...,
#          3.89800000e+00,  1.74000000e+02,  7.53760200e+00]])

# %%
list_of_names = Selector.get_feature_names_out(input_features=None)

# %%
X_test = pd.DataFrame(X_test)
X_test.columns = list_of_names
X_test
# Out:
#      ALogP    ALogp2      AMR       apol  naAromAtom  nAromBond  nAtom  \
# 0  -1.1628  1.352104  47.7649  69.364239        18.0       19.0   57.0
# 1  -0.4155  0.172640  54.8174  79.176583        21.0       23.0   67.0
# 2   0.2621  0.068696  56.8592  68.188825        17.0       18.0   60.0
# 3   0.8192  0.671089  56.7211  77.486411        21.0       23.0   64.0
# 4   0.5291  0.279947  44.0969  68.847032        21.0       24.0   56.0
# ..     ...       ...      ...        ...         ...        ...    ...
# 63 -0.1148  0.013179  35.6297  63.495860        21.0       24.0   53.0
# 64 -1.0554  1.113869  71.5682  88.826134        18.0       19.0   77.0
# 65 -0.2678  0.071717  63.9795  60.039446        12.0       12.0   52.0
# 66  0.4260  0.181476  62.1658  59.237446        12.0       12.0   51.0
# 67 -0.9199  0.846216  61.0438  69.229411        15.0       17.0   59.0
#
#     nHeavyAtom    nH    nC  ...          MW     WTPT-1     WTPT-3     WTPT-4  \
# ...

# %%
X_test.to_csv('/Users/irfanularifa/Documents/TA_FIX/0. Dataset/X_test.csv', index=False)
y_test.to_csv('/Users/irfanularifa/Documents/TA_FIX/0. Dataset/y_test.csv', index=False)
